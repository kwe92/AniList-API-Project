# %% [markdown]
# ## Project goal
#
# - Write a custom graphQL query
# - Connect to the AniList API
# - Extract data on animes with an average score of 85 or high
# - Data to retrieve id, season, episodes, averageScore, popularity, countryOfOrigin, genres, status, title, startDate, endDate
# - Transform and clean json data
# - Load aniList data into a in-memory SQL database for querying
# - Vizualize the count of top animes released by year

# %% [markdown]
# ## Import needed libraries

# %%
import requests                  # Allows you to send HTTP/S calls easily, we will use this for API calls
import pandas as pd              # Our data analysis tool
from InMemDB import InMemDB      # An easy way to create a guiless database in memory
from datetime import datetime    # datetime library, we will use this on some of our date objects
import warnings                  # used to turn off and filter warnings
import matplotlib.pyplot as plt  # a data visualization library
import seaborn as sns            # a data visualization library
# %matplotlib notebook
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ## Define Functions
# - We are going to have to do some clean up, I have defined a few helper functions to assist with that

# %%
def getDateInfo(row):
    
    m = row['month']
    m = str(m).replace('None','1')
    d = row['day']
    d = str(d).replace('None','1')
    y = row['year']
    y = str(y).replace('None','2099')
    
    startDate = m + '-' + d + '-' + y
    
    return pd.to_datetime(startDate).strftime('%m-%d-%Y')

#------------------------------------------------------------------------------------

def listToString(s): 
    str1 = ""
    for ele in s:
        str1 += ele + ', '  
     
    return str1.strip()[:-1]

#------------------------------------------------------------------------------------

def returnYear(row):
    row = pd.to_datetime(row)
    return row.year

# %% [markdown]
# ## GraphQL Query Strings
#
# - Create a list of API request queries to iterate through as there is a page limit of 50

# %%
queryList = []

for i in range(3):
    query = """

                query ($id: Int) {
                    Page """ + f'(page:{i + 1})' + """
                    
                    {

                    pageInfo {
                            total
                            currentPage
                            lastPage
                            hasNextPage
                            perPage
                        }

                    media (id: $id, averageScore_greater: 85) 

                    {
                    id

                    title {
                      english
                      romaji
                      userPreferred
                    }

                      season
                    , episodes
                    , averageScore
                    , popularity
                    , countryOfOrigin
                    , genres
                    , startDate {
                      year
                      month
                      day
                    }
                    , endDate {
                      year
                      month
                      day
                    }
                    , status 
                      }
                    }
                  }
                    """
    queryList.append(query)

# %% [markdown]
# ## Request JSON data from the AniList API
#
# - AniList does not require us to have an API key
# - So we can just call the endpoint https://graphql.anilist.co
# - Passing in the query strings we wrote

# %%
aniListData = [
                requests.post(
                      url = 'https://graphql.anilist.co'
                    , json={'query':q}
                    , verify = False).json() for q in queryList
                ]
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'graphql.anilist.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Applications/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'graphql.anilist.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(
# /Applications/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py:1013: InsecureRequestWarning: Unverified HTTPS request is being made to host 'graphql.anilist.co'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn(

# %% [markdown]
# ## Slice JSON Data
# - The JSON data we recieved is deeply nested so we need to do some slicing

# %%
aniListData[0]['data']['Page']['media'][0:3]
# Out:
# [{'id': 85976,
#   'title': {'english': 'Overlord',
#    'romaji': 'Overlord',
#    'userPreferred': 'Overlord'},
#   'season': None,
#   'episodes': None,
#   'averageScore': 85,
#   'popularity': 10574,
#   'countryOfOrigin': 'JP',
#   'genres': ['Action',
#    'Adventure',
#    'Comedy',
#    'Fantasy',
#    'Horror',
#    'Supernatural'],
#   'startDate': {'year': 2012, 'month': 6, 'day': 30},
#   'endDate': {'year': None, 'month': None, 'day': None},
#   'status': 'RELEASING'},
#  {'id': 98263,
#   'title': {'english': 'Witch Hat Atelier',
#    'romaji': 'Tongari Boushi no Atelier',
#    'userPreferred': 'Tongari Boushi no Atelier'},
#   'season': None,
#   'episodes': None,
#   'averageScore': 85,
#   'popularity': 24434,
#   'countryOfOrigin': 'JP',
#   'genres': ['Adventure', 'Drama', 'Fantasy'],
#   'startDate': {'year': 2016, 'month': 7, 'day': 22},
#   'endDate': {'year': None, 'month': None, 'day': None},
#   'status': 'RELEASING'},
#  {'id': 437,
#   'title': {'english': 'Perfect Blue',
#    'romaji': 'PERFECT BLUE',
#    'userPreferred': 'PERFECT BLUE'},
#   'season': 'WINTER',
#   'episodes': 1,
#   'averageScore': 85,
#   'popularity': 120383,
#   'countryOfOrigin': 'JP',
#   'genres': ['Drama', 'Horror', 'Psychological', 'Thriller'],
#   'startDate': {'year': 1998, 'month': 2, 'day': 28},
#   'endDate': {'year': 1998, 'month': 2, 'day': 28},
#   'status': 'FINISHED'}]

# %%
pd.DataFrame(aniListData[0]['data']['Page']['media']).head(5)
# Out:
#       id                                              title  season  episodes  \
# 0  85976  {'english': 'Overlord', 'romaji': 'Overlord', ...    None       NaN
# 1  98263  {'english': 'Witch Hat Atelier', 'romaji': 'To...    None       NaN
# 2    437  {'english': 'Perfect Blue', 'romaji': 'PERFECT...  WINTER       1.0
# 3    457  {'english': 'MUSHI-SHI', 'romaji': 'Mushishi',...    FALL      26.0
# 4    918  {'english': 'Gintama', 'romaji': 'Gintama', 'u...  SPRING     201.0
#
#    averageScore  popularity countryOfOrigin  \
# 0            85       10574              JP
# 1            85       24434              JP
# 2            85      120383              JP
# 3            85      113951              JP
# 4            85      174005              JP
#
#                                               genres  \
# 0  [Action, Adventure, Comedy, Fantasy, Horror, S...
# 1                        [Adventure, Drama, Fantasy]
# 2           [Drama, Horror, Psychological, Thriller]
# 3  [Adventure, Fantasy, Mystery, Psychological, S...
# 4                    [Action, Comedy, Drama, Sci-Fi]
#
#                                 startDate  \
# 0   {'year': 2012, 'month': 6, 'day': 30}
# 1   {'year': 2016, 'month': 7, 'day': 22}
# 2   {'year': 1998, 'month': 2, 'day': 28}
# 3  {'year': 2005, 'month': 10, 'day': 23}
# 4    {'year': 2006, 'month': 4, 'day': 4}
#
#                                       endDate     status
# 0  {'year': None, 'month': None, 'day': None}  RELEASING
# 1  {'year': None, 'month': None, 'day': None}  RELEASING
# 2       {'year': 1998, 'month': 2, 'day': 28}   FINISHED
# 3       {'year': 2006, 'month': 6, 'day': 19}   FINISHED
# 4       {'year': 2010, 'month': 3, 'day': 25}   FINISHED

# %% [markdown]
# ## Convert the list of dictionaries into a list of DataFrames

# %%
aniListDF = [pd.DataFrame(d['data']['Page']['media']) for d in aniListData]

# %%
aniListDF[0].head(3)
# Out:
#       id                                              title  season  episodes  \
# 0  85976  {'english': 'Overlord', 'romaji': 'Overlord', ...    None       NaN
# 1  98263  {'english': 'Witch Hat Atelier', 'romaji': 'To...    None       NaN
# 2    437  {'english': 'Perfect Blue', 'romaji': 'PERFECT...  WINTER       1.0
#
#    averageScore  popularity countryOfOrigin  \
# 0            85       10574              JP
# 1            85       24434              JP
# 2            85      120383              JP
#
#                                               genres  \
# 0  [Action, Adventure, Comedy, Fantasy, Horror, S...
# 1                        [Adventure, Drama, Fantasy]
# 2           [Drama, Horror, Psychological, Thriller]
#
#                                startDate  \
# 0  {'year': 2012, 'month': 6, 'day': 30}
# 1  {'year': 2016, 'month': 7, 'day': 22}
# 2  {'year': 1998, 'month': 2, 'day': 28}
#
#                                       endDate     status
# 0  {'year': None, 'month': None, 'day': None}  RELEASING
# 1  {'year': None, 'month': None, 'day': None}  RELEASING
# 2       {'year': 1998, 'month': 2, 'day': 28}   FINISHED

# %%
aniListDF[0].head(3)
# Out:
#       id                                              title  season  episodes  \
# 0  85976  {'english': 'Overlord', 'romaji': 'Overlord', ...    None       NaN
# 1  98263  {'english': 'Witch Hat Atelier', 'romaji': 'To...    None       NaN
# 2    437  {'english': 'Perfect Blue', 'romaji': 'PERFECT...  WINTER       1.0
#
#    averageScore  popularity countryOfOrigin  \
# 0            85       10574              JP
# 1            85       24434              JP
# 2            85      120383              JP
#
#                                               genres  \
# 0  [Action, Adventure, Comedy, Fantasy, Horror, S...
# 1                        [Adventure, Drama, Fantasy]
# 2           [Drama, Horror, Psychological, Thriller]
#
#                                startDate  \
# 0  {'year': 2012, 'month': 6, 'day': 30}
# 1  {'year': 2016, 'month': 7, 'day': 22}
# 2  {'year': 1998, 'month': 2, 'day': 28}
#
#                                       endDate     status
# 0  {'year': None, 'month': None, 'day': None}  RELEASING
# 1  {'year': None, 'month': None, 'day': None}  RELEASING
# 2       {'year': 1998, 'month': 2, 'day': 28}   FINISHED

# %% [markdown]
# ## Concatenate the DataFrames into one

# %%
aniListDF = pd.concat(aniListDF).reset_index(drop=True)

# %%
len(aniListDF)
# Out:
# 150

# %% [markdown]
# ## Data Exploration & Cleaning
# - We have more nested data in the title, grenes, startDate and endDate columns

# %%
aniListDF.head(2)
# Out:
#       id                                              title season  episodes  \
# 0  85976  {'english': 'Overlord', 'romaji': 'Overlord', ...   None       NaN
# 1  98263  {'english': 'Witch Hat Atelier', 'romaji': 'To...   None       NaN
#
#    averageScore  popularity countryOfOrigin  \
# 0            85       10574              JP
# 1            85       24434              JP
#
#                                               genres  \
# 0  [Action, Adventure, Comedy, Fantasy, Horror, S...
# 1                        [Adventure, Drama, Fantasy]
#
#                                startDate  \
# 0  {'year': 2012, 'month': 6, 'day': 30}
# 1  {'year': 2016, 'month': 7, 'day': 22}
#
#                                       endDate     status
# 0  {'year': None, 'month': None, 'day': None}  RELEASING
# 1  {'year': None, 'month': None, 'day': None}  RELEASING

# %%
aniListDF['title'][0]
# Out:
# {'english': 'Overlord', 'romaji': 'Overlord', 'userPreferred': 'Overlord'}

# %%
aniListDF['title'][0]['english']
# Out:
# 'Overlord'

# %% [markdown]
# ### Create a Column For Each Title Type

# %%
aniListDF['English Title'] = [aniListDF['title'][i]['english'] for i in range(len(aniListDF))]

# %%
aniListDF['Romaji Title'] = [aniListDF['title'][i]['romaji'] for i in range(len(aniListDF))]

# %%
aniListDF['userPreferred Title'] = [aniListDF['title'][i]['userPreferred'] for i in range(len(aniListDF))]

# %%
aniListDF.drop(columns={'title'}, inplace=True)

# %%
aniListDF.head(4)
# Out:
#       id  season  episodes  averageScore  popularity countryOfOrigin  \
# 0  85976    None       NaN            85       10574              JP
# 1  98263    None       NaN            85       24434              JP
# 2    437  WINTER       1.0            85      120383              JP
# 3    457    FALL      26.0            85      113951              JP
#
#                                               genres  \
# 0  [Action, Adventure, Comedy, Fantasy, Horror, S...
# 1                        [Adventure, Drama, Fantasy]
# 2           [Drama, Horror, Psychological, Thriller]
# 3  [Adventure, Fantasy, Mystery, Psychological, S...
#
#                                 startDate  \
# 0   {'year': 2012, 'month': 6, 'day': 30}
# 1   {'year': 2016, 'month': 7, 'day': 22}
# 2   {'year': 1998, 'month': 2, 'day': 28}
# 3  {'year': 2005, 'month': 10, 'day': 23}
#
#                                       endDate     status      English Title  \
# 0  {'year': None, 'month': None, 'day': None}  RELEASING           Overlord
# 1  {'year': None, 'month': None, 'day': None}  RELEASING  Witch Hat Atelier
# 2       {'year': 1998, 'month': 2, 'day': 28}   FINISHED       Perfect Blue
# 3       {'year': 2006, 'month': 6, 'day': 19}   FINISHED          MUSHI-SHI
#
#                 Romaji Title        userPreferred Title
# 0                   Overlord                   Overlord
# 1  Tongari Boushi no Atelier  Tongari Boushi no Atelier
# 2               PERFECT BLUE               PERFECT BLUE
# 3                   Mushishi                   Mushishi

# %% [markdown]
# ### Clean The Dates
# - When you are working with data typically the transformation of dates is a regular task

# %%
aniListDF['startDate'][0]['year']
# Out:
# 2012

# %%
type(aniListDF['startDate'][0]['year'])
# Out:
# int

# %%
dateKeys = list(aniListDF['startDate'][0].keys())
dateKeys
# Out:
# ['year', 'month', 'day']

# %%
aniListDF['startDate'].head()
# Out:
# 0     {'year': 2012, 'month': 6, 'day': 30}
# 1     {'year': 2016, 'month': 7, 'day': 22}
# 2     {'year': 1998, 'month': 2, 'day': 28}
# 3    {'year': 2005, 'month': 10, 'day': 23}
# 4      {'year': 2006, 'month': 4, 'day': 4}
# Name: startDate, dtype: object

# %%
aniListDF.apply(lambda row: getDateInfo(row['startDate']), axis=1).values[:6]
# Out:
# array(['06-30-2012', '07-22-2016', '02-28-1998', '10-23-2005',
#        '04-04-2006', '01-07-2009'], dtype=object)

# %%
aniListDF['startDate2'] = aniListDF.apply(lambda row: getDateInfo(row['startDate']), axis=1)

# %%
aniListDF['endDate2'] = aniListDF.apply(lambda row: getDateInfo(row['endDate']), axis=1)

# %%
aniListDF.head(4)
# Out:
#       id  season  episodes  averageScore  popularity countryOfOrigin  \
# 0  85976    None       NaN            85       10574              JP
# 1  98263    None       NaN            85       24434              JP
# 2    437  WINTER       1.0            85      120383              JP
# 3    457    FALL      26.0            85      113951              JP
#
#                                               genres  \
# 0  [Action, Adventure, Comedy, Fantasy, Horror, S...
# 1                        [Adventure, Drama, Fantasy]
# 2           [Drama, Horror, Psychological, Thriller]
# 3  [Adventure, Fantasy, Mystery, Psychological, S...
#
#                                 startDate  \
# 0   {'year': 2012, 'month': 6, 'day': 30}
# 1   {'year': 2016, 'month': 7, 'day': 22}
# 2   {'year': 1998, 'month': 2, 'day': 28}
# 3  {'year': 2005, 'month': 10, 'day': 23}
#
#                                       endDate     status      English Title  \
# 0  {'year': None, 'month': None, 'day': None}  RELEASING           Overlord
# 1  {'year': None, 'month': None, 'day': None}  RELEASING  Witch Hat Atelier
# 2       {'year': 1998, 'month': 2, 'day': 28}   FINISHED       Perfect Blue
# 3       {'year': 2006, 'month': 6, 'day': 19}   FINISHED          MUSHI-SHI
#
#                 Romaji Title        userPreferred Title  startDate2  \
# 0                   Overlord                   Overlord  06-30-2012
# 1  Tongari Boushi no Atelier  Tongari Boushi no Atelier  07-22-2016
# 2               PERFECT BLUE               PERFECT BLUE  02-28-1998
# 3                   Mushishi                   Mushishi  10-23-2005
#
#      endDate2
# 0  01-01-2099
# 1  01-01-2099
# 2  02-28-1998
# 3  06-19-2006

# %%
aniListDF.drop(['startDate','endDate'], axis=1, inplace=True)

# %%
aniListDF.rename(columns={'startDate2':'startDate', 'endDate2':'endDate'},inplace=True)

# %%
aniListDF.columns
# Out:
# Index(['id', 'season', 'episodes', 'averageScore', 'popularity',
#        'countryOfOrigin', 'genres', 'status', 'English Title', 'Romaji Title',
#        'userPreferred Title', 'startDate', 'endDate'],
#       dtype='object')

# %%
aniListDF['startYear'] = aniListDF.startDate.apply(returnYear)

# %%
aniListDF[['genres']].head(5)
# Out:
#                                               genres
# 0  [Action, Adventure, Comedy, Fantasy, Horror, S...
# 1                        [Adventure, Drama, Fantasy]
# 2           [Drama, Horror, Psychological, Thriller]
# 3  [Adventure, Fantasy, Mystery, Psychological, S...
# 4                    [Action, Comedy, Drama, Sci-Fi]

# %%
aniListDF['genres'] = aniListDF['genres'].apply(lambda row: listToString(row))

# %% [markdown]
# ## Cleaned Data

# %%
aniListDF.head(5)
# Out:
#       id  season  episodes  averageScore  popularity countryOfOrigin  \
# 0  85976    None       NaN            85       10574              JP
# 1  98263    None       NaN            85       24434              JP
# 2    437  WINTER       1.0            85      120383              JP
# 3    457    FALL      26.0            85      113951              JP
# 4    918  SPRING     201.0            85      174005              JP
#
#                                               genres     status  \
# 0  Action, Adventure, Comedy, Fantasy, Horror, Su...  RELEASING
# 1                          Adventure, Drama, Fantasy  RELEASING
# 2             Drama, Horror, Psychological, Thriller   FINISHED
# 3  Adventure, Fantasy, Mystery, Psychological, Sl...   FINISHED
# 4                      Action, Comedy, Drama, Sci-Fi   FINISHED
#
#        English Title               Romaji Title        userPreferred Title  \
# 0           Overlord                   Overlord                   Overlord
# 1  Witch Hat Atelier  Tongari Boushi no Atelier  Tongari Boushi no Atelier
# 2       Perfect Blue               PERFECT BLUE               PERFECT BLUE
# 3          MUSHI-SHI                   Mushishi                   Mushishi
# 4            Gintama                    Gintama                    Gintama
#
#     startDate     endDate  startYear
# 0  06-30-2012  01-01-2099       2012
# 1  07-22-2016  01-01-2099       2016
# 2  02-28-1998  02-28-1998       1998
# 3  10-23-2005  06-19-2006       2005
# 4  04-04-2006  03-25-2010       2006

# %% [markdown]
# ## Import InMemDB
#
# - Queries:
#     - Return animes with an average score above 90
#     - Return top romantic comedies
#     - Return the count of top animes released by year

# %%
db = InMemDB()

# %%
db.CreateTableDF(df = aniListDF, table_name='aniList')
# Out:
# 'aniList table has been created successfully'

# %%
dbQuery1 = '''

select * from aniList
where averageScore > 90

'''

# %%
db.query(dbQuery1)
# Out:
#        id  season  episodes  averageScore  popularity countryOfOrigin  \
# 0   20996  SPRING      51.0            91       76122              JP
# 1  124194  SPRING      13.0            91       95798              JP
# 2   30656    None       NaN            91       71866              JP
#
#                                               genres     status  \
# 0                      Action, Comedy, Drama, Sci-Fi   FINISHED
# 1  Comedy, Drama, Psychological, Romance, Slice o...   FINISHED
# 2                           Action, Adventure, Drama  RELEASING
#
#                     English Title              Romaji Title  \
# 0                Gintama Season 4                  Gintama°
# 1  Fruits Basket The Final Season  Fruits Basket: The Final
# 2                        Vagabond                  Vagabond
#
#         userPreferred Title   startDate     endDate  startYear
# 0                  Gintama°  04-08-2015  03-30-2016       2015
# 1  Fruits Basket: The Final  04-06-2021  06-29-2021       2021
# 2                  Vagabond  03-23-1999  01-01-2099       1999

# %%
dbQuery2 = '''

select * from aniList
where genres like ('%Comedy%')
and genres like ('%Romance%')

'''

# %%
db.query(dbQuery2).head(5)
# Out:
#       id  season  episodes  averageScore  popularity countryOfOrigin  \
# 0   7785  SPRING      11.0            85       92087              JP
# 1  30102    None       NaN            85       22044              JP
# 2  70171    None       NaN            85       13697              JP
# 3  85849    None       NaN            85       35731              JP
# 4  98842    None       NaN            85       47213              JP
#
#                                               genres     status  \
# 0            Comedy, Mystery, Psychological, Romance   FINISHED
# 1  Comedy, Drama, Psychological, Romance, Superna...   FINISHED
# 2              Comedy, Drama, Romance, Slice of Life   FINISHED
# 3  Comedy, Drama, Psychological, Romance, Slice o...   FINISHED
# 4  Action, Comedy, Drama, Mystery, Romance, Super...  RELEASING
#
#                                       English Title  \
# 0                                 The Tatami Galaxy
# 1                                     Fruits Basket
# 2  My Youth Romantic Comedy Is Wrong, As I Expected
# 3                                            ReLIFE
# 4                           Toilet-Bound Hanako-kun
#
#                                         Romaji Title  \
# 0                             Yojouhan Shinwa Taikei
# 1                                      Fruits Basket
# 2  Yahari Ore no Seishun Love Come wa Machigatteiru.
# 3                                             ReLife
# 4                          Jibaku Shounen Hanako-kun
#
#                                  userPreferred Title   startDate     endDate  \
# 0                             Yojouhan Shinwa Taikei  04-23-2010  07-02-2010
# 1                                      Fruits Basket  07-18-1998  11-20-2006
# 2  Yahari Ore no Seishun Love Come wa Machigatteiru.  03-23-2011  04-20-2021
# 3                                             ReLife  10-12-2013  03-16-2018
# 4                          Jibaku Shounen Hanako-kun  06-18-2014  01-01-2099
#
#    startYear
# 0       2010
# 1       1998
# 2       2011
# 3       2013
# 4       2014

# %%
dbQuery3 = """

select startYear, count(id) as [Anime Count]
from aniList
group by startYear

"""

# %%
releaseByYearDF = db.query(dbQuery3)

releaseByYearDF.head(5)
# Out:
#    startYear  Anime Count
# 0       1968            1
# 1       1980            1
# 2       1985            1
# 3       1988            1
# 4       1989            1

# %% [markdown]
# ## Test Case (Data vizualization with matplotlib)
#
# - of the top animes how many were realeased each year?

# %%
plt.figure(figsize=(7, 5))
sns.lineplot(x=releaseByYearDF.startYear, y=releaseByYearDF['Anime Count'], size=3)
plt.title('Top Animes by Release Year')
plt.xlabel('Year')
plt.show()
# Out:
# <div id='9ca07c58-b844-4d4f-b7a3-aecb787d898b'></div>
